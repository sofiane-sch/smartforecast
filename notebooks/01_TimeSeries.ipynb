# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from ipywidgets import interact

# %%
def linear_trend(x:np.array, coeff:float=1, intercept:float=0):
    return coeff*x + intercept

def exponential_trend(x:np.array, coeff:float=1, intercept:float=0):
    return np.exp(x) + intercept - 1

def seasonality(x:np.array, freq:float=1, phi:float=0):
    return np.sin(2*np.pi*freq*x + phi)

# %%
np.arange(2,10,1)
# Out:
# array([2, 3, 4, 5, 6, 7, 8, 9])

# %%
time = np.arange(101)

# %%
fig = go.Figure()

# Add traces, one for each slider step
for frequency in np.arange(0, 0.05, 0.001):
    fig.add_trace(
        go.Scatter(
            visible=False,
            line=dict(color="#00CED1", width=6),
            name="𝜈 = " + str(frequency),
            x=time,
            y=seasonality(time, frequency)))

# Make 10th trace visible
fig.data[10].visible = True

# Create and add slider
steps = []
for i in range(len(fig.data)):
    step = dict(
        method="update",
        args=[{"visible": [False] * len(fig.data)},
              {"title": "Slider switched to step: " + str(i)}],  # layout attribute
    )
    step["args"][0]["visible"][i] = True  # Toggle i'th trace to "visible"
    steps.append(step)

sliders = [dict(
    active=10,
    currentvalue={"prefix": "Frequency: "},
    pad={"t": 50},
    steps=steps
)]

fig.update_layout(
    sliders=sliders
)

fig.show()

# %%
xs=np.linspace(0, 6, 100)
fig = go.FigureWidget()
scatt = fig.add_scatter()
fig

@interact(a=(1.0, 4.0, 0.01), b=(0, 10.0, 0.01), color=['red', 'green', 'blue'])
def update(a=3.6, b=4.3, color='blue'):
    with fig.batch_update():
        scatt.x=xs
        scatt.y=np.sin(a*xs-b)
        scatt.line.color=color
# Out:
# interactive(children=(FloatSlider(value=3.6, description='a', max=4.0, min=1.0, step=0.01), FloatSlider(value=…
